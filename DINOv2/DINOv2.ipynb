# %% [markdown]
# # DINOv2

# %%
pip install torch torchvision transformers timm accelerate
# Out:
# Requirement already satisfied: torch in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (2.8.0)
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: transformers in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (5.0.0.dev0)
# Collecting timm
#   Downloading timm-1.0.20-py3-none-any.whl.metadata (61 kB)
# Collecting accelerate
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: huggingface-hub==1.0.0.rc2 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (1.0.0rc2)
# Requirement already satisfied: packaging>=20.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from huggingface-hub==1.0.0.rc2->transformers) (0.28.1)
# Requirement already satisfied: typer-slim in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from huggingface-hub==1.0.0.rc2->transformers) (0.19.2)
# Requirement already satisfied: anyio in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc2->transformers) (4.7.0)
# Requirement already satisfied: certifi in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc2->transformers) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc2->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc2->transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc2->transformers) (0.16.0)
# Requirement already satisfied: psutil in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub==1.0.0.rc2->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\c00531\appdata\local\anaconda3\lib\site-packages (from typer-slim->huggingface-hub==1.0.0.rc2->transformers) (8.1.8)
# Downloading torchvision-0.23.0-cp313-cp313-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 36.0 MB/s eta 0:00:00
# Downloading timm-1.0.20-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 49.9 MB/s eta 0:00:00
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
# Installing collected packages: torchvision, timm, accelerate
#
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ---------------------------------------- 0/3 [torchvision]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    ------------- -------------------------- 1/3 [timm]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    ---------------------------------------- 3/3 [accelerate]
#
# Successfully installed accelerate-1.10.1 timm-1.0.20 torchvision-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoImageProcessor, AutoModel
import torch
from PIL import Image
import requests
import numpy as np
import os

# %% [markdown]
# ## Compare embedding similarity between two objects

# %%
processor = AutoImageProcessor.from_pretrained("facebook/dinov2-base")
model = AutoModel.from_pretrained("facebook/dinov2-base")

def get_embedding(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(images=image, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    # Average the patch embeddings
    emb = outputs.last_hidden_state.mean(dim=1)
    return emb / emb.norm()  # normalize

# Example images
emb1 = get_embedding("data\detected_['tree']_0.663.jpg")
emb2 = get_embedding("data\detected_['tree']_0.663.jpg")

similarity = torch.nn.functional.cosine_similarity(emb1, emb2)
print("Cosine similarity:", similarity.item())
# Out:
# Cosine similarity: 1.0

# %% [markdown]
# ## Compare against reference species embeddings

# %%
from transformers import AutoImageProcessor, AutoModel
from PIL import Image, ImageFile
import torch
import os
import numpy as np

# Handle truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Load DINOv2
processor = AutoImageProcessor.from_pretrained("facebook/dinov2-base")
model = AutoModel.from_pretrained("facebook/dinov2-base").eval()

def get_embedding(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(images=image, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    emb = outputs.last_hidden_state.mean(dim=1)
    emb = emb / emb.norm()  # normalize
    return emb.cpu()

# -----------------------------------------------------------------
# 1️⃣ Build reference library (your known tree species)
# Folder structure example:
# data/
#   meranti_1.jpg, meranti_2.jpg
#   angsana_1.jpg, angsana_2.jpg
#   palm_1.jpg, palm_2.jpg
# -----------------------------------------------------------------

reference_dir = "data/"
species_embeddings = {}

for fname in os.listdir(reference_dir):
    if fname.endswith((".jpg", ".png")):
        species = fname.split(".")[0] 
        emb = get_embedding(os.path.join(reference_dir, fname))
        species_embeddings.setdefault(species, []).append(emb)

# Average embeddings per species
for species in species_embeddings:
    species_embeddings[species] = torch.stack(species_embeddings[species]).mean(dim=0)
    species_embeddings[species] = species_embeddings[species] / species_embeddings[species].norm()

# -----------------------------------------------------------------
# 2️⃣ Classify a new (unknown) tree image
# -----------------------------------------------------------------
test_image = "tree.jpeg"
test_emb = get_embedding(test_image)

# Compute cosine similarity with each species reference
scores = {}
for species, ref_emb in species_embeddings.items():
    sim = torch.nn.functional.cosine_similarity(test_emb, ref_emb)
    scores[species] = sim.item()

# Pick best match
pred_species = max(scores, key=scores.get)

print("Predicted species:", pred_species)
print("Similarity scores:", scores)
# Out:
# Predicted species: angsana
# Similarity scores: {'angsana': 0.7849617004394531, 'jambulaut': 0.47202053666114807, 'mempari': 0.5361167788505554, 'pulai': 0.6082491278648376}

# %% [markdown]
# ### Measuring accuracy

# %%
from transformers import AutoImageProcessor, AutoModel
import torch
from PIL import Image, ImageFile

# Handle truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Load DINOv2 model and processor
processor = AutoImageProcessor.from_pretrained("facebook/dinov2-base")
model = AutoModel.from_pretrained("facebook/dinov2-base").eval()

def get_embedding(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(images=image, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    emb = outputs.last_hidden_state.mean(dim=1)
    emb = emb / emb.norm()  # normalize
    return emb.cpu()
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
# Create reference embeddings for each species
reference_dir = "data/"
species_embeddings = {}

for fname in os.listdir(reference_dir):
    if fname.endswith((".jpg", ".png")):
        species = fname.split(".")[0] 
        emb = get_embedding(os.path.join(reference_dir, fname))
        species_embeddings.setdefault(species, []).append(emb)

# Average embeddings per species
for species in species_embeddings:
    species_embeddings[species] = torch.stack(species_embeddings[species]).mean(dim=0)
    species_embeddings[species] = species_embeddings[species] / species_embeddings[species].norm()

print("Created reference embeddings for species:", list(species_embeddings.keys()))
# Out:
# Created reference embeddings for species: ['angsana', 'jambulaut', 'pulai']

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import pandas as pd
import os

# Prepare lists for evaluation
y_true, y_pred = [], []

test_dir = "test/"
for fname in os.listdir(test_dir):
    if fname.endswith((".jpg", ".png")):
        true_species = fname.split("_")[0]  # extract label from filename
        test_image = os.path.join(test_dir, fname)
        test_emb = get_embedding(test_image)

        # Compare with reference embeddings
        scores = {}
        for species, ref_emb in species_embeddings.items():
            sim = torch.nn.functional.cosine_similarity(test_emb, ref_emb)
            scores[species] = sim.item()
        pred_species = max(scores, key=scores.get)

        y_true.append(true_species)
        y_pred.append(pred_species)

# Compute accuracy
acc = accuracy_score(y_true, y_pred)
print(f"Overall accuracy: {acc*100:.2f}%")

# Optional: confusion matrix
cm = pd.DataFrame(confusion_matrix(y_true, y_pred),
                    index=species_embeddings.keys(),
                    columns=species_embeddings.keys())
print("\nConfusion Matrix:")
print(cm)
# Out:
# Overall accuracy: 71.43%
#
# Confusion Matrix:
#            angsana  jambulaut  pulai
# angsana          2          0      0
# jambulaut        0          2      0
# pulai            1          1      1
