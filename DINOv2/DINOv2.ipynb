# %% [markdown]
# # DINOv2

# %%
# pip install torch torchvision transformers timm accelerate

# %%
from transformers import AutoImageProcessor, AutoModel
import torch
from PIL import Image
import requests
import numpy as np
import os

# %% [markdown]
# ## Compare embedding similarity between two objects

# %%
processor = AutoImageProcessor.from_pretrained("facebook/dinov2-base")
model = AutoModel.from_pretrained("facebook/dinov2-base")

def get_embedding(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(images=image, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    # Average the patch embeddings
    emb = outputs.last_hidden_state.mean(dim=1)
    return emb / emb.norm()  # normalize

# Example images
emb1 = get_embedding("angsana_tree.jpeg")
emb2 = get_embedding("data/angsana.png")

similarity = torch.nn.functional.cosine_similarity(emb1, emb2)
print("Cosine similarity:", similarity.item())
# Out:
# Cosine similarity: 0.725714921951294

# %% [markdown]
# ## Compare one tree against reference species embeddings

# %%
from transformers import AutoImageProcessor, AutoModel
from PIL import Image, ImageFile
import torch
import os
import numpy as np

# Handle truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Load DINOv2
processor = AutoImageProcessor.from_pretrained("facebook/dinov2-base")
model = AutoModel.from_pretrained("facebook/dinov2-base").eval()

def get_embedding(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(images=image, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    emb = outputs.last_hidden_state.mean(dim=1)
    emb = emb / emb.norm()  # normalize
    return emb.cpu()

# -----------------------------------------------------------------
# 1️⃣ Build reference library (local tree species)
# -----------------------------------------------------------------

reference_dir = "data/"
species_embeddings = {}

for fname in os.listdir(reference_dir):
    if fname.endswith((".jpg", ".png")):
        species = fname.split(".")[0] 
        reference_img = os.path.join(reference_dir, fname)
        emb = get_embedding(reference_img)
        species_embeddings.setdefault(species, []).append(emb)


# Average embeddings per species
for species in species_embeddings:
    species_embeddings[species] = torch.stack(species_embeddings[species]).mean(dim=0)
    species_embeddings[species] = species_embeddings[species] / species_embeddings[species].norm()

# -----------------------------------------------------------------
# 2️⃣ Classify an unknown tree image
# -----------------------------------------------------------------
test_image = "tree_0.503.jpg"
test_emb = get_embedding(test_image)

# Compute cosine similarity with each species reference
scores = {}
for species, ref_emb in species_embeddings.items():
    sim = torch.nn.functional.cosine_similarity(test_emb, ref_emb)
    scores[species] = sim.item()

# Pick best match
pred_species = max(scores, key=scores.get)

print("Tree to classify: ", test_image)
print("Predicted species:", pred_species)
print("Similarity scores:", scores)
# Out:
# Tree to classify:  tree_0.503.jpg
# Predicted species: pulai
# Similarity scores: {'angsana': 0.7050976753234863, 'jambulaut': 0.6492912173271179, 'pulai': 0.7664188146591187}

# %%
# Display test image and the matched species image
import matplotlib.pyplot as plt

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 5))

# Load and display test image
test_img = Image.open(test_image)
ax1.imshow(test_img)
ax1.set_title(f'Test Image\n({test_image})')
ax1.axis('off')

# Load and display the matched species reference image
ref_img = Image.open(reference_img)
ax2.imshow(ref_img)
ax2.set_title(f'Matched Species: {pred_species}\nSimilarity: {scores[pred_species]:.3f}')
ax2.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Measure accuracy

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import pandas as pd
import os

# Prepare lists for evaluation
y_true, y_pred = [], []

test_dir = "test/"
for fname in os.listdir(test_dir):
    if fname.endswith((".jpg", ".png")):
        true_species = fname.split("_")[0]  # extract label from filename
        test = os.path.join(test_dir, fname)
        test_emb = get_embedding(test)

        # Compare with reference embeddings
        scores = {}
        for species, ref_emb in species_embeddings.items():
            sim = torch.nn.functional.cosine_similarity(test_emb, ref_emb)
            scores[species] = sim.item()
        pred_species = max(scores, key=scores.get)

        y_true.append(true_species)
        y_pred.append(pred_species)

# Compute accuracy
acc = accuracy_score(y_true, y_pred)
print(f"Overall accuracy: {acc*100:.2f}%")

# Optional: confusion matrix
cm = pd.DataFrame(confusion_matrix(y_true, y_pred),
                    index=species_embeddings.keys(),
                    columns=species_embeddings.keys())
print("\nConfusion Matrix:")
print(cm)
# Out:
# Overall accuracy: 71.43%
#
# Confusion Matrix:
#            angsana  jambulaut  pulai
# angsana          2          0      0
# jambulaut        0          2      0
# pulai            1          1      1
